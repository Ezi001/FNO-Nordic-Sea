# %%
import numpy as np
from datetime import datetime


day_of_year = datetime.now().timetuple().tm_yday  # returns 1 for January 1st
print(day_of_year)
time_tuple = datetime.now().timetuple()
print(time_tuple)
# Out:
# 193
# time.struct_time(tm_year=2026, tm_mon=7, tm_mday=12, tm_hour=13, tm_min=27, tm_sec=30, tm_wday=6, tm_yday=193, tm_isdst=-1)

# %%
date_strings = ["2016-01-01 00:00:00", "2016-09-13 00:00:00", "2016-09-17 00:00:00", "2016-09-21 00:00:00", "2016-09-25 00:00:00", "2016-09-29 00:00:00", "2016-10-03 00:00:00", "2016-10-07 00:00:00"]

ics = []

for date_ in date_strings:
    date_obj = datetime.strptime(date_, '%Y-%m-%d %H:%M:%S') #datetime.fromisoformat(date_) 
    print(date_obj.timetuple())
    day_of_year = date_obj.timetuple().tm_yday - 1
    hour_of_day = date_obj.timetuple().tm_hour
    hours_since_jan_01_epoch = 24*day_of_year + hour_of_day
    ics.append(int(hours_since_jan_01_epoch/6))
    print(day_of_year, hour_of_day)
    print("hours = ", hours_since_jan_01_epoch )
    print("steps = ", hours_since_jan_01_epoch/6) 


print(ics)

ics = []
for date_ in date_strings:
    date_obj = datetime.fromisoformat(date_) #datetime.strptime(date_, '%Y-%m-%d %H:%M:%S') #datetime.fromisoformat(date_) 
    print(date_obj.timetuple())
    day_of_year = date_obj.timetuple().tm_yday - 1
    hour_of_day = date_obj.timetuple().tm_hour
    hours_since_jan_01_epoch = 24*day_of_year + hour_of_day
    ics.append(int(hours_since_jan_01_epoch/6))
    print(day_of_year, hour_of_day)
    print("hours = ", hours_since_jan_01_epoch )
    print("steps = ", hours_since_jan_01_epoch/6) 


print(ics)
# Out:
# time.struct_time(tm_year=2016, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=1, tm_isdst=-1)
# 0 0
# hours =  0
# steps =  0.0
# time.struct_time(tm_year=2016, tm_mon=9, tm_mday=13, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=257, tm_isdst=-1)
# 256 0
# hours =  6144
# steps =  1024.0
# time.struct_time(tm_year=2016, tm_mon=9, tm_mday=17, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=5, tm_yday=261, tm_isdst=-1)
# 260 0
# hours =  6240
# steps =  1040.0
# time.struct_time(tm_year=2016, tm_mon=9, tm_mday=21, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=265, tm_isdst=-1)
# 264 0
# hours =  6336
# steps =  1056.0
# time.struct_time(tm_year=2016, tm_mon=9, tm_mday=25, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=269, tm_isdst=-1)
# 268 0
# hours =  6432
# steps =  1072.0
# time.struct_time(tm_year=2016, tm_mon=9, tm_mday=29, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=273, tm_isdst=-1)
# 272 0
# hours =  6528
# steps =  1088.0
# time.struct_time(tm_year=2016, tm_mon=10, tm_mday=3, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=277, tm_isdst=-1)
# 276 0
# hours =  6624
# steps =  1104.0
# time.struct_time(tm_year=2016, tm_mon=10, tm_mday=7, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=281, tm_isdst=-1)
# 280 0
# hours =  6720
# steps =  1120.0
# [0, 1024, 1040, 1056, 1072, 1088, 1104, 1120]
# time.struct_time(tm_year=2016, tm_mon=1, tm_mday=1, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=1, tm_isdst=-1)
# 0 0
# hours =  0
# steps =  0.0
# time.struct_time(tm_year=2016, tm_mon=9, tm_mday=13, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=257, tm_isdst=-1)
# 256 0
# hours =  6144
# steps =  1024.0
# time.struct_time(tm_year=2016, tm_mon=9, tm_mday=17, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=5, tm_yday=261, tm_isdst=-1)
# 260 0
# hours =  6240
# steps =  1040.0
# time.struct_time(tm_year=2016, tm_mon=9, tm_mday=21, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=265, tm_isdst=-1)
# 264 0
# hours =  6336
# steps =  1056.0
# time.struct_time(tm_year=2016, tm_mon=9, tm_mday=25, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=6, tm_yday=269, tm_isdst=-1)
# 268 0
# hours =  6432
# steps =  1072.0
# time.struct_time(tm_year=2016, tm_mon=9, tm_mday=29, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=273, tm_isdst=-1)
# 272 0
# hours =  6528
# steps =  1088.0
# time.struct_time(tm_year=2016, tm_mon=10, tm_mday=3, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=0, tm_yday=277, tm_isdst=-1)
# 276 0
# hours =  6624
# steps =  1104.0
# time.struct_time(tm_year=2016, tm_mon=10, tm_mday=7, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=281, tm_isdst=-1)
# 280 0
# hours =  6720
# steps =  1120.0
# [0, 1024, 1040, 1056, 1072, 1088, 1104, 1120]
